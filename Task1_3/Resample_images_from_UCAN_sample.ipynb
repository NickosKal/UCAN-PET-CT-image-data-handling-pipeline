# %%
import numpy as np
import pandas as pd
import pydicom as dicom
import matplotlib.pylab as plt
import glob
import SimpleITK as sitk
import re
import random
random.seed(10)

import os

# Global Path variables
source_path = "/media/andres/T7 Shield/ucan_lymfom"
slicer_path = "/home/andres/Downloads/Slicer-4.10.2-linux-amd64/Slicer"
# 'C:\ProgramData\slicer.org\Slicer 5.4.0\Slicer'
data_path = os.path.join(source_path, 'Final_Selected_exams_from_U-CAN-Lymfom.xlsx')
destination_path = os.path.join(source_path, 'Selected_for_UCAN_project/Resampled_Selected_Sample_Images')

# %%
# %env SITK_SHOW_COMMAND "/home/andres/Downloads/Slicer-4.10.2-linux-amd64/Slicer"
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
dicom.config.convert_wrong_length_to_UN = True
# Out:
# env: SITK_SHOW_COMMAND="/home/andres/Downloads/Slicer-4.10.2-linux-amd64/Slicer"

# %%
master_data = pd.read_excel(data_path)
print(master_data.shape)
master_data.head()
# Out:
# (2264, 8)
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                        directory  \
# 0  /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr900031979078-20220919/PT-20220919-141702-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-QCFX-S_400_M.Free-2.8000mm
# 1   /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr900031979078-20220919/CT-20220919-143055-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-WB_Venfas_3_ax-3.000000mm
# 2  /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr748236341307-20220908/PT-20220908-103801-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-QCFX-S_400_M.Free-2.8000mm
# 3   /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr748236341307-20220908/CT-20220908-105049-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-WB_Venfas_3_ax-3.000000mm
# 4                   /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr652851209495-20220829/PT-20220829-124104-3.8_WB_F18_FDG_VENFAS-QCFX-S_400_M.Free-2.8000mm
#
#                       source_directory                     patient_directory  \
# 0  /media/andres/T7 Shield/ucan_lymfom  ASPTCTX0001_npr900031979078-20220919
# 1  /media/andres/T7 Shield/ucan_lymfom  ASPTCTX0001_npr900031979078-20220919
# 2  /media/andres/T7 Shield/ucan_lymfom  ASPTCTX0001_npr748236341307-20220908
# 3  /media/andres/T7 Shield/ucan_lymfom  ASPTCTX0001_npr748236341307-20220908
# 4  /media/andres/T7 Shield/ucan_lymfom  ASPTCTX0001_npr652851209495-20220829
#
#                                                                             PET-CT_info  \
# 0  PT-20220919-141702-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-QCFX-S_400_M.Free-2.8000mm
# 1   CT-20220919-143055-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-WB_Venfas_3_ax-3.000000mm
# 2  PT-20220908-103801-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-QCFX-S_400_M.Free-2.8000mm
# 3   CT-20220908-105049-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-WB_Venfas_3_ax-3.000000mm
# 4                   PT-20220829-124104-3.8_WB_F18_FDG_VENFAS-QCFX-S_400_M.Free-2.8000mm
#
#         system              npr  scan_date
# 0  ASPTCTX0001  npr900031979078   20220919
# 1  ASPTCTX0001  npr900031979078   20220919
# 2  ASPTCTX0001  npr748236341307   20220908
# 3  ASPTCTX0001  npr748236341307   20220908
# 4  ASPTCTX0001  npr652851209495   20220829

# %%
patdir_list = list(set(master_data['patient_directory'].to_list()))

# %%
sampledir = random.sample(patdir_list,5)
print(len(sampledir))
print(sampledir)
# Out:
# 5
# ['ASPTCTX0001_npr406981575115-20220325', 'ASPTCTX0001_npr476083448226-20170411', 'ASPTCTX0001_npr485030831082-20220517', 'ASPTCTX0001_npr136457009354-20191223', 'ASPTCTX0001_npr588137148278-20150303']

# %%
sample_df = master_data[master_data.patient_directory.isin(sampledir)].copy()
print(sample_df.shape)
sample_df[sample_df['PET-CT_info'].str.contains('CT')].shape
# Out:
# (10, 8)
# (7, 8)

# %%
sample_df['num_slices'].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/UCANProject/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/UCANProject/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/UCANProject/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'num_slices'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/andres/VSCode/UCAN-PET-CT-image-data-handling-pipeline/Task 1.3/Resample_images_from_UCAN_sample.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/home/andres/VSCode/UCAN-PET-CT-image-data-handling-pipeline/Task%201.3/Resample_images_from_UCAN_sample.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> sample_df['num_slices'].to_list()
#
# File ~/anaconda3/envs/UCANProject/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/UCANProject/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'num_slices'

# %%
r"""
Skipped_images:
F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm

distorted : npr648969352384_CT-20160318-150152-6.6-UAS-WB-FDG-3D-VENFASTHORAX-INSP-20160120-WB-VEN-AX-0.964844mm_.nii.gz
"""
# Out:
# '\nSkipped_images:\nF:\\U-CAN-Lymfom_A\\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\\ASPTCTX0001_npr252097509348-20180509\\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm\n'

# %%
new_size = [356, 356, 356]
new_spacing = [2, 2, 3]

# %%
for index, row in sample_df.iterrows():

    #vol_img = sitk.ReadImage(row['directory'])
    
    print(row['directory'])

    reader = sitk.ImageSeriesReader()
    dicom_names = reader.GetGDCMSeriesFileNames(row['directory'])
    reader.SetFileNames(dicom_names)
    vol_img = reader.Execute()
        
    #res_img = resample_volume(vol_img, sitk.sitkLinear, new_size, new_spacing)
    
    res_img = sitk.Resample(vol_img, new_size, sitk.Transform(), sitk.sitkLinear,
                         vol_img.GetOrigin(), new_spacing, vol_img.GetDirection(), 0,
                         vol_img.GetPixelID())

    sitk.WriteImage(image = res_img, fileName = destination_path + '_' +
                    str(row['npr']) + '_' + str(row['PET-CT_info']) + '_.nii.gz')
# Out:
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr485030831082-20220517/PT-20220517-144331-3.8_WB_F18_FDG_VENFAS-QCFX-S_400_M.Free-2.8000mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr485030831082-20220517/CT-20220517-145542-3.8_WB_F18_FDG_VENFAS-WB_Venfas_3_ax-3.000000mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr406981575115-20220325/PT-20220325-090400-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-QCFX-S_400_M.Free-2.8000mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr406981575115-20220325/CT-20220325-091723-3.11_WB_F18_FDG_VENFAS__THORAX_INANDAD-WB_Venfas_3_ax-3.000000mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr136457009354-20191223/PT-20191223-102800-3.7_WB_FDG_CT_VENFAS-QCFX-S_400-2.7900mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr136457009354-20191223/CT-20191223-104136-3.7_WB_FDG_CT_VENFAS-WB_Venfas_3_ax-3.000000mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr476083448226-20170411/PT-20170411-115946-6.39_WB_FDG_CT_NATIV-WB_AC_FDG_VPFX-S-2.7900mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr476083448226-20170411/CT-20170411-115800-6.39_WB_FDG_CT_NATIV-WB_Standard_0.6_ax-0.625000mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr588137148278-20150303/PT-20150303-152219-UAS-WB-FDG-3D-UAS-WB-FDG-3D-AC-3.2700mm
# /media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr588137148278-20150303/CT-20150303-152042-6.1_UAS-WB-FDG-3D-STANDARD_CT_RECON-3.750000mm

# %%
if not os.path.exists(destination_path):
        os.makedirs(destination_path)

# %%
reader = sitk.ImageSeriesReader()
#dicom_names = reader.GetGDCMSeriesFileNames(r'F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm')
dicom_names = reader.GetGDCMSeriesFileNames('/media/andres/T7 Shield/ucan_lymfom/ASPTCTX0001_npr207978513481-20190903/CT-20190903-122850-3.6_WB_FDG_CT_VENFAS-WB_Venfas_3_ax-3.000000mm')
reader.SetFileNames(dicom_names)
vol_img = reader.Execute()

res_img = sitk.Resample(vol_img, new_size, sitk.Transform(), sitk.sitkLinear,
                        vol_img.GetOrigin(), new_spacing, vol_img.GetDirection(), 0,
                        vol_img.GetPixelID())

# sitk.WriteImage(image = res_img, fileName = r'D:\ucan_lymfom\Selected_for_UCAN_project\Resampled_Selected_SampleImages\\CT_sample3Dimg_.nii.gz')
# Out:
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.3/itkImageSeriesReader.hxx, line 477
# ImageSeriesReader (0x4264110): Non uniform sampling or missing slices detected,  maximum nonuniformity:914.997

# %%
print(vol_img.GetSize())
print(res_img.GetSize())
# Out:
# (512, 512, 762)
# (356, 356, 356)

# %%
dimg = sitk.GetArrayFromImage(vol_img)
print(dimg.max())
print(dimg.min())
# Out:
# 3071
# -1024

# %%
reader = sitk.ImageSeriesReader()
dicom_names = reader.GetGDCMSeriesFileNames(r'F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221205__06__n86_90GB\ASPTCTX0001_npr462153436708-20220302\PT-20220302-130601-3.8-WB-F18-FDG-VENFAS-QCFX-S-400-M.Free-2.8000mm_JK')
reader.SetFileNames(dicom_names)
vol_img = reader.Execute()
dimg = sitk.GetArrayFromImage(vol_img)
print(dimg.max())
print(dimg.min())
# Out:
# 34410.92039
# 0.0

# %%
dicom_names = r'F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm'
master_data[master_data['directory'] == dicom_names]
# Out:
#                                                                                                                                                                         directory  \
# 194  F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm
#
#      root_directory                                   source_directory  \
# 194  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
#
#                                                                                                  patient_info  \
# 194  ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm
#
#                         patient_directory  \
# 194  ASPTCTX0001_npr252097509348-20180509
#
#                                                              PET-CT_info  \
# 194  CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm
#
#                                            dicom_img       patient_id  \
# 194  1.2.840.113619.2.5.1207072.12420.1525686926.934  npr252097509348
#
#      patient_age patient_weight patient_size  imgsz_x  imgsz_y  num_slices  \
# 194         74.0         '77.0'       '1.64'      512      512        1151
#
#       voxsz_x   voxsz_y  slice_thickness        image_size  \
# 194  1.571045  1.571045         0.976562  (512, 512, 1151)
#
#                          voxel_size                                img_pos  \
# 194  (1.571045, 1.571045, 0.976562)   [-0.488281, -402.187500, 121.687500]
#
#                                                          img_orient  \
# 194   [0.000000, 1.000000, 0.000000, 0.000000, 0.000000, -1.000000]
#
#                                                           for_uid att_corr  \
# 194   1.2.840.113619.2.55.3.4240671514.620.1525680322.102.12550.1      NaN
#
#     recons_method                                image_type aquisition_dt  \
# 194           NaN   ['DERIVED', 'SECONDARY', 'REFORMATTED']    '20180509'
#
#             study_desc   series_desc                        protocol corr_img  \
# 194   'PET FDG WB 1 h'   'WB VEN AX'   '6.3 UAS-WB-FDG-3D CT VENFAS'      NaN
#
#     modality           manufacturer manufacturer_model
# 194     'CT'   'GE MEDICAL SYSTEMS'    'Discovery STE'

# %%
dicom_names1 = r'F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.949219mm'
master_data[master_data['directory'] == dicom_names1]
# Out:
# Empty DataFrame
# Columns: [directory, root_directory, source_directory, patient_info, patient_directory, PET-CT_info, dicom_img, patient_id, patient_age, patient_weight, patient_size, imgsz_x, imgsz_y, num_slices, voxsz_x, voxsz_y, slice_thickness, image_size, voxel_size, img_pos, img_orient, for_uid, att_corr, recons_method, image_type, aquisition_dt, study_desc, series_desc, protocol, corr_img, modality, manufacturer, manufacturer_model]
# Index: []

# %%
metadata = pd.read_excel(r'F:\U-CAN-Lymfom_A\Ashish_SampleResampling\metadata_extraction\metadata_extract_29Sep2023.xlsx')
metadata.head(1)
# Out:
#                                                                                                                                                                                dir  \
# 0  F:/U-CAN-Lymfom_A\Raw_DCM_transf_date_20221205__06__n86_90GB\ASPTCTX0001_npr258071002437-20160805\CT-20160805-124130-6.3-UAS-WB-FDG-3D-CT-VENFAS-CT-SCOUT-HEAD-IN-1250.090942mm
#
#                                    source_dir  \
# 0  Raw_DCM_transf_date_20221205__06__n86_90GB
#
#                             patient_dir  \
# 0  ASPTCTX0001_npr258071002437-20160805
#
#                                                                        image_dir  \
# 0  CT-20160805-124130-6.3-UAS-WB-FDG-3D-CT-VENFAS-CT-SCOUT-HEAD-IN-1250.090942mm
#
#                                                dicom_img  \
# 0  1.2.840.113619.2.55.3.4240671514.785.1470288679.289.1
#
#                        patient_id patient_age patient_sex patient_weight  \
# 0   'ASPTCTX0001_npr258071002437'      '070Y'         'O'         '46.0'
#
#   patient_size  rows  columns  imgsz_x  imgsz_y  num_slices   voxsz_x  \
# 0       '1.56'  2291      888     2291      888           1  0.545455
#
#     voxsz_y  slice_thickness          pixel_spacing      image_size  \
# 0  0.596847      1250.090942   [0.545455, 0.596847]  (2291, 888, 1)
#
#                           voxel_size                      img_pos  \
# 0  (0.545455, 0.596847, 1250.090942)   [-265.000, 0.000, 350.000]
#
#                                                         img_orient  \
# 0   [1.000000, -0.000000, 0.000000, 0.000000, 0.000000, -1.000000]
#
#                                                         for_uid att_corr  \
# 0   1.2.840.113619.2.55.3.4240671514.785.1470288679.287.12920.1      NaN
#
#   recons_method                             image_type aquisition_dt  \
# 0           NaN   ['ORIGINAL', 'PRIMARY', 'LOCALIZER']    '20160805'
#
#           study_desc          series_desc                        protocol  \
# 0   'PET FDG WB 1 h'   'CT SCOUT HEAD IN'   '6.3 UAS-WB-FDG-3D CT VENFAS'
#
#   corr_img modality           manufacturer manufacturer_model
# 0      NaN     'CT'   'GE MEDICAL SYSTEMS'    'Discovery STE'

# %%
img = 'CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm'
img2 = 'CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.949219mm'
metadata[np.logical_or(metadata['image_dir'] == img2, metadata['image_dir'] == img)]
# Out:
#                                                                                                                                                                                dir  \
# 4641  F:/U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.949219mm
# 4642  F:/U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr252097509348-20180509\CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm
#
#                                              source_dir  \
# 4641  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
# 4642  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
#
#                                patient_dir  \
# 4641  ASPTCTX0001_npr252097509348-20180509
# 4642  ASPTCTX0001_npr252097509348-20180509
#
#                                                                 image_dir  \
# 4641  CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.949219mm
# 4642  CT-20180509-103313-6.3-UAS-WB-FDG-3D-CT-VENFAS-WB-VEN-AX-0.976562mm
#
#                                             dicom_img  \
# 4641  1.2.840.113619.2.5.1207072.12420.1525686926.935
# 4642  1.2.840.113619.2.5.1207072.12420.1525686926.934
#
#                           patient_id patient_age patient_sex patient_weight  \
# 4641   'ASPTCTX0001_npr252097509348'      '074Y'         'O'         '77.0'
# 4642   'ASPTCTX0001_npr252097509348'      '074Y'         'O'         '77.0'
#
#      patient_size  rows  columns  imgsz_x  imgsz_y  num_slices   voxsz_x  \
# 4641       '1.64'   512      512      512      512        1151  0.976562
# 4642       '1.64'   512      512      512      512        1151  1.571045
#
#        voxsz_y  slice_thickness          pixel_spacing        image_size  \
# 4641  0.976562         0.949219   [0.976562, 0.976562]  (512, 512, 1151)
# 4642  1.571045         0.976562   [1.571045, 1.571045]  (512, 512, 1151)
#
#                           voxel_size                                  img_pos  \
# 4641  (0.976562, 0.976562, 0.949219)   [-250.488281, -229.980469, 121.962494]
# 4642  (1.571045, 1.571045, 0.976562)     [-0.488281, -402.187500, 121.687500]
#
#                                                           img_orient  \
# 4641    [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# 4642   [0.000000, 1.000000, 0.000000, 0.000000, 0.000000, -1.000000]
#
#                                                            for_uid att_corr  \
# 4641   1.2.840.113619.2.55.3.4240671514.620.1525680322.102.12550.1      NaN
# 4642   1.2.840.113619.2.55.3.4240671514.620.1525680322.102.12550.1      NaN
#
#      recons_method                                           image_type  \
# 4641           NaN   ['DERIVED', 'SECONDARY', 'REFORMATTED', 'AVERAGE']
# 4642           NaN              ['DERIVED', 'SECONDARY', 'REFORMATTED']
#
#      aquisition_dt         study_desc   series_desc  \
# 4641    '20180509'   'PET FDG WB 1 h'   'WB VEN AX'
# 4642    '20180509'   'PET FDG WB 1 h'   'WB VEN AX'
#
#                             protocol corr_img modality           manufacturer  \
# 4641   '6.3 UAS-WB-FDG-3D CT VENFAS'      NaN     'CT'   'GE MEDICAL SYSTEMS'
# 4642   '6.3 UAS-WB-FDG-3D CT VENFAS'      NaN     'CT'   'GE MEDICAL SYSTEMS'
#
#      manufacturer_model
# 4641    'Discovery STE'
# 4642    'Discovery STE'

# %%
patientgrp = master_data.groupby(['patient_directory']).agg({'dicom_img':'count'}).reset_index()
patientgrp[patientgrp['dicom_img']!=2]
# Out:
#                         patient_directory  dicom_img
# 34   ASPTCTX0001_npr150867785519-20131210          1
# 42   ASPTCTX0001_npr167850885413-20160620          3
# 73   ASPTCTX0001_npr218702301637-20161020          1
# 101  ASPTCTX0001_npr252097509348-20170725          1
# 140  ASPTCTX0001_npr284872448692-20160921          1
# 143  ASPTCTX0001_npr290047476872-20161220          1
# 153  ASPTCTX0001_npr292781072009-20180409          1
# 169  ASPTCTX0001_npr314033739598-20151215          1
# 192  ASPTCTX0001_npr338511978351-20170201          1
# 193  ASPTCTX0001_npr338511978351-20170531          1
# 242  ASPTCTX0001_npr389797559525-20181030          1
# 244  ASPTCTX0001_npr391123015354-20151125          1
# 276  ASPTCTX0001_npr428194397030-20170807          1
# 280  ASPTCTX0001_npr433060402747-20200625          1
# 369  ASPTCTX0001_npr530844574765-20160909          1
# 416  ASPTCTX0001_npr600444694366-20151215          1
# 426  ASPTCTX0001_npr611298776180-20170725          1
# 427  ASPTCTX0001_npr612146277420-20161220          1
# 447  ASPTCTX0001_npr640031899533-20180316          1
# 468  ASPTCTX0001_npr652851209495-20180409          1
# 538  ASPTCTX0001_npr738871065625-20170310          1
# 562  ASPTCTX0001_npr772741368693-20170201          1
# 571  ASPTCTX0001_npr787080102148-20180702          1
# 579  ASPTCTX0001_npr788802379464-20180702          1
# 587  ASPTCTX0001_npr798819050410-20150923          1
# 603  ASPTCTX0001_npr823815545590-20170113          1
# 610  ASPTCTX0001_npr834522932360-20170112          1
# 637  ASPTCTX0001_npr877253951206-20181029          3
# 638  ASPTCTX0001_npr878181444975-20170310          1
# 642  ASPTCTX0001_npr884176295970-20160921          1
# 644  ASPTCTX0001_npr884176295970-20170619          3
# 655  ASPTCTX0001_npr900215850414-20160909          1
# 672  ASPTCTX0001_npr937959980599-20180202          1
# 687  ASPTCTX0001_npr962157381216-20180202          1

# %%
master_data[master_data['patient_directory']=='ASPTCTX0001_npr877253951206-20181029']
# Out:
#                                                                                                                                                                          directory  \
# 871  F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr877253951206-20181029\CT-20181029-140238-6.39-WB_FDG-CT-VENFAS-WB-Venfas-0.6-ax-0.625000mm
# 872    F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr877253951206-20181029\CT-20181030-072512-6.39-WB_FDG-CT-VENFAS-WB-Venfas-3-ax-3.000000mm
# 873          F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr877253951206-20181029\PT-20181029-135206-6.39-WB_FDG-CT-VENFAS-QCFX-S-400-2.7900mm
#
#      root_directory                                   source_directory  \
# 871  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
# 872  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
# 873  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
#
#                                                                                                   patient_info  \
# 871  ASPTCTX0001_npr877253951206-20181029\CT-20181029-140238-6.39-WB_FDG-CT-VENFAS-WB-Venfas-0.6-ax-0.625000mm
# 872    ASPTCTX0001_npr877253951206-20181029\CT-20181030-072512-6.39-WB_FDG-CT-VENFAS-WB-Venfas-3-ax-3.000000mm
# 873          ASPTCTX0001_npr877253951206-20181029\PT-20181029-135206-6.39-WB_FDG-CT-VENFAS-QCFX-S-400-2.7900mm
#
#                         patient_directory  \
# 871  ASPTCTX0001_npr877253951206-20181029
# 872  ASPTCTX0001_npr877253951206-20181029
# 873  ASPTCTX0001_npr877253951206-20181029
#
#                                                               PET-CT_info  \
# 871  CT-20181029-140238-6.39-WB_FDG-CT-VENFAS-WB-Venfas-0.6-ax-0.625000mm
# 872    CT-20181030-072512-6.39-WB_FDG-CT-VENFAS-WB-Venfas-3-ax-3.000000mm
# 873          PT-20181029-135206-6.39-WB_FDG-CT-VENFAS-QCFX-S-400-2.7900mm
#
#                                                   dicom_img       patient_id  \
# 871  1.2.840.113619.2.405.3.2831160321.842.1540794498.931.1  npr877253951206
# 872      1.2.840.113619.2.5.4250371947.12760.1540806994.836  npr877253951206
# 873       1.2.840.113619.2.405.2831160321.1540817816.268514  npr877253951206
#
#      patient_age patient_weight patient_size  imgsz_x  imgsz_y  num_slices  \
# 871         75.0         '50.0'       '1.58'      512      512        1283
# 872         75.0         '50.0'       '1.58'      512      512         322
# 873         75.0         '50.0'       '1.58'      256      256         287
#
#       voxsz_x   voxsz_y  slice_thickness        image_size  \
# 871  0.976562  0.976562            0.625  (512, 512, 1283)
# 872  0.976562  0.976562            3.000   (512, 512, 322)
# 873  1.953125  1.953125            2.790   (256, 256, 287)
#
#                       voxel_size  \
# 871  (0.976562, 0.976562, 0.625)
# 872    (0.976562, 0.976562, 3.0)
# 873   (1.953125, 1.953125, 2.79)
#
#                                                      img_pos  \
# 871                              [-250.000, -250.000, 6.810]
# 872                              [-241.699, -213.378, 6.184]
# 873   [-249.02343750000, -249.02343750000, -792.69000244140]
#
#                                                         img_orient  \
# 871   [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# 872   [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# 873                                            [1, 0, 0, 0, 1, -0]
#
#                                                           for_uid  \
# 871   1.2.840.113619.2.405.3.2831160321.842.1540794498.408.7450.1
# 872   1.2.840.113619.2.405.3.2831160321.842.1540794498.408.7450.1
# 873   1.2.840.113619.2.405.3.2831160321.842.1540794498.408.7450.1
#
#                                             att_corr recons_method  \
# 871                                              NaN           NaN
# 872                                              NaN           NaN
# 873   'measured,, 0.000000 cm-1, attenuation smooth'        'QCFX'
#
#                                               image_type aquisition_dt  \
# 871                     ['ORIGINAL', 'PRIMARY', 'AXIAL']    '20181029'
# 872   ['DERIVED', 'SECONDARY', 'REFORMATTED', 'AVERAGE']    '20181029'
# 873                              ['ORIGINAL', 'PRIMARY']    '20181029'
#
#             study_desc          series_desc                  protocol  \
# 871   'PET FDG WB 1 h'   'WB Venfas 0.6 ax'   '6.39 WB_FDG CT VENFAS'
# 872   'PET FDG WB 1 h'     'WB Venfas 3 ax'   '6.39 WB_FDG CT VENFAS'
# 873   'PET FDG WB 1 h'         'QCFX-S 400'   '6.39 WB_FDG CT VENFAS'
#
#                                                                   corr_img  \
# 871                                                                    NaN
# 872                                                                    NaN
# 873   ['DECY', 'ATTN', 'SCAT', 'DTIM', 'RANSNG', 'DCAL', 'SLSENS', 'NORM']
#
#     modality           manufacturer manufacturer_model
# 871     'CT'   'GE MEDICAL SYSTEMS'     'Discovery MI'
# 872     'CT'   'GE MEDICAL SYSTEMS'     'Discovery MI'
# 873     'PT'   'GE MEDICAL SYSTEMS'     'Discovery MI'

# %%
master_data[master_data['patient_directory']=='ASPTCTX0001_npr877253951206-20181029']
# Out:
#                                                                                                                                                                          directory  \
# 871  F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr877253951206-20181029\CT-20181029-140238-6.39-WB_FDG-CT-VENFAS-WB-Venfas-0.6-ax-0.625000mm
# 872    F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr877253951206-20181029\CT-20181030-072512-6.39-WB_FDG-CT-VENFAS-WB-Venfas-3-ax-3.000000mm
# 873          F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr877253951206-20181029\PT-20181029-135206-6.39-WB_FDG-CT-VENFAS-QCFX-S-400-2.7900mm
#
#      root_directory                                   source_directory  \
# 871  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
# 872  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
# 873  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
#
#                                                                                                   patient_info  \
# 871  ASPTCTX0001_npr877253951206-20181029\CT-20181029-140238-6.39-WB_FDG-CT-VENFAS-WB-Venfas-0.6-ax-0.625000mm
# 872    ASPTCTX0001_npr877253951206-20181029\CT-20181030-072512-6.39-WB_FDG-CT-VENFAS-WB-Venfas-3-ax-3.000000mm
# 873          ASPTCTX0001_npr877253951206-20181029\PT-20181029-135206-6.39-WB_FDG-CT-VENFAS-QCFX-S-400-2.7900mm
#
#                         patient_directory  \
# 871  ASPTCTX0001_npr877253951206-20181029
# 872  ASPTCTX0001_npr877253951206-20181029
# 873  ASPTCTX0001_npr877253951206-20181029
#
#                                                               PET-CT_info  \
# 871  CT-20181029-140238-6.39-WB_FDG-CT-VENFAS-WB-Venfas-0.6-ax-0.625000mm
# 872    CT-20181030-072512-6.39-WB_FDG-CT-VENFAS-WB-Venfas-3-ax-3.000000mm
# 873          PT-20181029-135206-6.39-WB_FDG-CT-VENFAS-QCFX-S-400-2.7900mm
#
#                                                   dicom_img       patient_id  \
# 871  1.2.840.113619.2.405.3.2831160321.842.1540794498.931.1  npr877253951206
# 872      1.2.840.113619.2.5.4250371947.12760.1540806994.836  npr877253951206
# 873       1.2.840.113619.2.405.2831160321.1540817816.268514  npr877253951206
#
#      patient_age patient_weight patient_size  imgsz_x  imgsz_y  num_slices  \
# 871         75.0         '50.0'       '1.58'      512      512        1283
# 872         75.0         '50.0'       '1.58'      512      512         322
# 873         75.0         '50.0'       '1.58'      256      256         287
#
#       voxsz_x   voxsz_y  slice_thickness        image_size  \
# 871  0.976562  0.976562            0.625  (512, 512, 1283)
# 872  0.976562  0.976562            3.000   (512, 512, 322)
# 873  1.953125  1.953125            2.790   (256, 256, 287)
#
#                       voxel_size  \
# 871  (0.976562, 0.976562, 0.625)
# 872    (0.976562, 0.976562, 3.0)
# 873   (1.953125, 1.953125, 2.79)
#
#                                                      img_pos  \
# 871                              [-250.000, -250.000, 6.810]
# 872                              [-241.699, -213.378, 6.184]
# 873   [-249.02343750000, -249.02343750000, -792.69000244140]
#
#                                                         img_orient  \
# 871   [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# 872   [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# 873                                            [1, 0, 0, 0, 1, -0]
#
#                                                           for_uid  \
# 871   1.2.840.113619.2.405.3.2831160321.842.1540794498.408.7450.1
# 872   1.2.840.113619.2.405.3.2831160321.842.1540794498.408.7450.1
# 873   1.2.840.113619.2.405.3.2831160321.842.1540794498.408.7450.1
#
#                                             att_corr recons_method  \
# 871                                              NaN           NaN
# 872                                              NaN           NaN
# 873   'measured,, 0.000000 cm-1, attenuation smooth'        'QCFX'
#
#                                               image_type aquisition_dt  \
# 871                     ['ORIGINAL', 'PRIMARY', 'AXIAL']    '20181029'
# 872   ['DERIVED', 'SECONDARY', 'REFORMATTED', 'AVERAGE']    '20181029'
# 873                              ['ORIGINAL', 'PRIMARY']    '20181029'
#
#             study_desc          series_desc                  protocol  \
# 871   'PET FDG WB 1 h'   'WB Venfas 0.6 ax'   '6.39 WB_FDG CT VENFAS'
# 872   'PET FDG WB 1 h'     'WB Venfas 3 ax'   '6.39 WB_FDG CT VENFAS'
# 873   'PET FDG WB 1 h'         'QCFX-S 400'   '6.39 WB_FDG CT VENFAS'
#
#                                                                   corr_img  \
# 871                                                                    NaN
# 872                                                                    NaN
# 873   ['DECY', 'ATTN', 'SCAT', 'DTIM', 'RANSNG', 'DCAL', 'SLSENS', 'NORM']
#
#     modality           manufacturer manufacturer_model
# 871     'CT'   'GE MEDICAL SYSTEMS'     'Discovery MI'
# 872     'CT'   'GE MEDICAL SYSTEMS'     'Discovery MI'
# 873     'PT'   'GE MEDICAL SYSTEMS'     'Discovery MI'

# %%
master_data[master_data['patient_directory']=='ASPTCTX0001_npr391123015354-20151125']
# Out:
#                                                                                                                                                                                       directory  \
# 363  F:\U-CAN-Lymfom_A\Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc\ASPTCTX0001_npr391123015354-20151125\PT-20151125-105902-UAS-WB-FDG-3D-CT-THORAX-BUK-VENFAS-20141209-WB-FDG-AC-3.2700mm
#
#      root_directory                                   source_directory  \
# 363  U-CAN-Lymfom_A  Raw_DCM_transf_date_20221211__14_n574_1.2TBondisc
#
#                                                                                                                patient_info  \
# 363  ASPTCTX0001_npr391123015354-20151125\PT-20151125-105902-UAS-WB-FDG-3D-CT-THORAX-BUK-VENFAS-20141209-WB-FDG-AC-3.2700mm
#
#                         patient_directory  \
# 363  ASPTCTX0001_npr391123015354-20151125
#
#                                                                            PET-CT_info  \
# 363  PT-20151125-105902-UAS-WB-FDG-3D-CT-THORAX-BUK-VENFAS-20141209-WB-FDG-AC-3.2700mm
#
#                                              dicom_img       patient_id  \
# 363  1.2.840.113619.2.131.4240671514.1448445893.483663  npr391123015354
#
#      patient_age patient_weight patient_size  imgsz_x  imgsz_y  num_slices  \
# 363         71.0         '55.0'       '1.54'      128      128         247
#
#      voxsz_x  voxsz_y  slice_thickness       image_size  \
# 363  3.90625  3.90625             3.27  (128, 128, 247)
#
#                    voxel_size  \
# 363  (3.90625, 3.90625, 3.27)
#
#                                                      img_pos  \
# 363   [-248.04687500000, -248.04687500000, -671.90002441406]
#
#                img_orient  \
# 363   [1, 0, 0, 0, 1, -0]
#
#                                                           for_uid  \
# 363   1.2.840.113619.2.55.3.4240671514.949.1447163216.740.12830.1
#
#                          att_corr recons_method                image_type  \
# 363   'measured,, 0.096000 cm-1,'       '3D IR'   ['ORIGINAL', 'PRIMARY']
#
#     aquisition_dt     study_desc   series_desc  \
# 363    '20151125'   'FDG WB 1 h'   'WB-FDG-AC'
#
#                                                 protocol  \
# 363   'UAS-WB-FDG-3D CT THORAX-BUK VENFAS      20141209'
#
#                                                                corr_img  \
# 363   ['DECY', 'ATTN', 'SCAT', 'DTIM', 'RAN', 'DCAL', 'SLSENS', 'NORM']
#
#     modality           manufacturer manufacturer_model
# 363     'PT'   'GE MEDICAL SYSTEMS'    'Discovery STE'

# %%
master_data.patient_id.nunique()
# Out:
# 481

# %%
master_data.patient_directory.nunique()
# Out:
# 705

# %%
patientgrp[patientgrp['dicom_img']==2].shape
# Out:
# (671, 2)
